# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 경고 무시 설정
import warnings
warnings.filterwarnings(action='ignore')

# 한글 깨짐 방지
plt.rcParams['font.family'] = 'Malgun Gothic'
# 마이너스 부호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 부산 영도구 노인요양시설

# %%
df00 = pd.read_csv('./영도구_장기요양기관내역.csv')
df00
# Out:
#     연번       장기요양기관         급여종류                 평가결과   정원  현원  잔여 대기 방문목욕차량  \
# 0    1    파랑새노인건강센터    치매전담실나형1실  A (최우수)\n2025\n정기평가    0   0   0  0    NaN
# 1    2    파랑새노인건강센터    치매전담실나형2실  A (최우수)\n2025\n정기평가    0   0   0  0    NaN
# 2    3  혜원영도구노인복지센터        주야간보호  A (최우수)\n2023\n정기평가   19  16   3  0    NaN
# 3    4     영도주간보호센터        주야간보호   C (양호)\n2024\n정기평가   81  67  14  0    NaN
# 4    5    다사랑장기요양기관        주야간보호   C (양호)\n2024\n정기평가   31  27   4  0    NaN
# ..  ..          ...          ...                  ...  ...  ..  .. ..    ...
# 94  95    신기의료기 영도점         복지용구                 신설기관    -   -   -  -    NaN
# 95  96       드림복지용구         복지용구                 신설기관    -   -   -  -    NaN
# 96  97        영도요양원  노인요양시설(개정법)  A (최우수)\n2025\n정기평가   29  29   0  0    NaN
# 97  98    파랑새노인건강센터  노인요양시설(개정법)  A (최우수)\n2025\n정기평가  123  88  35  0    NaN
# 98  99      부산사랑실버홈  노인요양시설(개정법)   C (양호)\n2025\n정기평가   14  13   1  0    NaN
#
#        주소          전화번호
# ...

# %%
df02 = df00['주소'].value_counts()
df02
# Out:
# 주소
# 청학동      27
# 동삼동      23
# 영선동1가     8
# 영선동3가     7
# 영선동2가     5
# 영선동4가     5
# 신선동1가     5
# 봉래동3가     4
# 대교동1가     4
# 봉래동4가     2
# 대평동1가     2
# 남항동1가     2
# 남항동3가     2
# 봉래동5가     2
# 대교동2가     1
# Name: count, dtype: int64

# %%
df02.plot(kind='bar', color='skyblue', figsize=(10, 6))
plt.title('영도구 동별 장기요양기관 수')
plt.xlabel('동')
plt.ylabel('기관 수')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 3. 막대 그래프 그리기
plt.figure(figsize=(10, 6))
bars = plt.bar(df02.index, df02.values, color='skyblue')

# 4. 그래프 상단에 숫자 적기 (핵심 로직)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height, f'{int(height)}', 
             ha='center', va='bottom', fontsize=11, fontweight='bold')

# 5. 그래프 꾸미기
plt.title('영도구 동별 장기요양기관 수', fontsize=15, pad=15)
plt.xlabel('동', fontsize=12)
plt.ylabel('기관 수(개)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
df01 = df00['급여종류'].value_counts()
df01
# Out:
# 급여종류
# 방문요양           49
# 방문목욕           29
# 주야간보호           9
# 복지용구            6
# 노인요양시설(개정법)     3
# 치매전담실나형1실       1
# 치매전담실나형2실       1
# 방문간호            1
# Name: count, dtype: int64

# %%
df01.plot(kind='bar', color='skyblue', figsize=(10, 6))
plt.title('영도구 급여종류별 장기요양기관 수')
plt.xlabel('급여종류')
plt.ylabel('기관 수')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 3. 막대 그래프 그리기
plt.figure(figsize=(10, 6))
bars = plt.bar(df01.index, df01.values, color='skyblue')

# 4. 그래프 상단에 숫자 적기 (핵심 로직)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height, f'{int(height)}', 
             ha='center', va='bottom', fontsize=11, fontweight='bold')

# 5. 그래프 꾸미기
plt.title('영도구 급여종류별 장기요양기관 수', fontsize=15, pad=15)
plt.xlabel('급여종류', fontsize=12)
plt.ylabel('기관 수(개)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. 데이터 로드
df_yeongdo = pd.read_csv('영도구_장기요양기관내역.csv')

# 2. 주소에 '청학동'이 포함된 데이터만 필터링 (결측치 제외)
df_chunghak = df_yeongdo[df_yeongdo['주소'].str.contains('청학동', na=False)].copy()

# 3. '급여종류'별 개수 계산
chunghak_counts = df_chunghak['급여종류'].value_counts()

# 4. 막대 그래프 그리기
plt.figure(figsize=(10, 6))
bars = plt.bar(chunghak_counts.index, chunghak_counts.values, color='skyblue')

# 5. 그래프 상단에 숫자 표시
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height, f'{int(height)}', 
             ha='center', va='bottom', fontsize=11, fontweight='bold')

# 6. 그래프 꾸미기
plt.title('영도구 청학동 급여종류별 장기요양기관 현황', fontsize=15, pad=15)
plt.xlabel('급여종류', fontsize=12)
plt.ylabel('기관 수(개)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. 데이터 로드
df_yeongdo = pd.read_csv('영도구_장기요양기관내역.csv')

# 2. 주소에 '청학동'이 포함된 데이터만 필터링 (결측치 제외)
df_chunghak = df_yeongdo[df_yeongdo['주소'].str.contains('동삼동', na=False)].copy()

# 3. '급여종류'별 개수 계산
chunghak_counts = df_chunghak['급여종류'].value_counts()

# 4. 막대 그래프 그리기
plt.figure(figsize=(10, 6))
bars = plt.bar(chunghak_counts.index, chunghak_counts.values, color='skyblue')

# 5. 그래프 상단에 숫자 표시
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height, f'{int(height)}', 
             ha='center', va='bottom', fontsize=11, fontweight='bold')

# 6. 그래프 꾸미기
plt.title('영도구 동삼동 급여종류별 장기요양기관 현황', fontsize=15, pad=15)
plt.xlabel('급여종류', fontsize=12)
plt.ylabel('기관 수(개)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. 데이터 로드
df_yeongdo = pd.read_csv('영도구_장기요양기관내역.csv')

# 2. 주소에 '청학동'이 포함된 데이터만 필터링 (결측치 제외)
df_chunghak = df_yeongdo[df_yeongdo['주소'].str.contains('영선동4가', na=False)].copy()

# 3. '급여종류'별 개수 계산
chunghak_counts = df_chunghak['급여종류'].value_counts()

# 4. 막대 그래프 그리기
plt.figure(figsize=(10, 6))
bars = plt.bar(chunghak_counts.index, chunghak_counts.values, color='skyblue')

# 5. 그래프 상단에 숫자 표시
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height, f'{int(height)}', 
             ha='center', va='bottom', fontsize=11, fontweight='bold')

# 6. 그래프 꾸미기
plt.title('영도구 영선동4가 급여종류별 장기요양기관 현황', fontsize=15, pad=15)
plt.xlabel('급여종류', fontsize=12)
plt.ylabel('기관 수(개)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. 데이터 로드
df_yeongdo = pd.read_csv('영도구_장기요양기관내역.csv')

# 2. 주소에 '청학동'이 포함된 데이터만 필터링 (결측치 제외)
df_chunghak = df_yeongdo[df_yeongdo['주소'].str.contains('봉래동4가', na=False)].copy()

# 3. '급여종류'별 개수 계산
chunghak_counts = df_chunghak['급여종류'].value_counts()

# 4. 막대 그래프 그리기
plt.figure(figsize=(10, 6))
bars = plt.bar(chunghak_counts.index, chunghak_counts.values, color='skyblue')

# 5. 그래프 상단에 숫자 표시
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height, f'{int(height)}', 
             ha='center', va='bottom', fontsize=11, fontweight='bold')

# 6. 그래프 꾸미기
plt.title('영도구 봉래동4가 급여종류별 장기요양기관 현황', fontsize=15, pad=15)
plt.xlabel('급여종류', fontsize=12)
plt.ylabel('기관 수(개)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. 데이터 로드
df_yeongdo = pd.read_csv('영도구_장기요양기관내역.csv')

# 2. 주소에 '청학동'이 포함된 데이터만 필터링 (결측치 제외)
df_chunghak = df_yeongdo[df_yeongdo['주소'].str.contains('봉래동5가', na=False)].copy()

# 3. '급여종류'별 개수 계산
chunghak_counts = df_chunghak['급여종류'].value_counts()

# 4. 막대 그래프 그리기
plt.figure(figsize=(10, 6))
bars = plt.bar(chunghak_counts.index, chunghak_counts.values, color='skyblue')

# 5. 그래프 상단에 숫자 표시
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height, f'{int(height)}', 
             ha='center', va='bottom', fontsize=11, fontweight='bold')

# 6. 그래프 꾸미기
plt.title('영도구 봉래동5가 급여종류별 장기요양기관 현황', fontsize=15, pad=15)
plt.xlabel('급여종류', fontsize=12)
plt.ylabel('기관 수(개)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
