# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 경고 무시 설정
import warnings
warnings.filterwarnings(action='ignore')

# 한글 깨짐 방지
plt.rcParams['font.family'] = 'Malgun Gothic'
# 마이너스 부호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### [데이터 로드]

# %%
weather = pd.read_csv('./전남_일별_기상청_데이터_최종수정.csv')
weather.head()
# Out:
#     지점 지점명          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  일강수량(mm)  평균 풍속(m/s)  \
# 0  165  목포  2014-05-01      15.4      10.6      20.3       0.0         1.6
# 1  165  목포  2014-05-02      15.6      12.0      23.3       0.0         4.4
# 2  165  목포  2014-05-03      13.4      10.0      19.3       0.0         5.6
# 3  165  목포  2014-05-04      13.6       9.6      20.0       1.0         3.9
# 4  165  목포  2014-05-05      12.6       8.7      17.3       0.0         4.2
#
#    평균 이슬점온도(°C)  평균 상대습도(%)  합계 일조시간(hr)
# 0          12.0        82.5         12.2
# 1          13.6        88.5          7.3
# 2           9.2        77.5         12.2
# 3           9.3        78.9          3.0
# 4           4.6        60.0         12.1

# %%
rice = pd.read_csv('./통합_논벼_예찰결과_피해율유지.csv')
rice.head()
# Out:
#           조사일   지역  이삭도열병  흰잎마름병  세균벼알마름병  깨씨무늬병    벼멸구  흰등멸구  혹명나방  먹노린재  \
# 0  2014.09.16  강진군  0.070   0.14    0.020   0.00  0.000  1.11   0.0  0.28
# 1  2014.09.16  고흥군  0.009   0.00    0.000   0.11  0.071  0.00   0.0  0.00
# 2  2014.09.16  곡성군  0.080   0.00    0.000   0.17  0.000  0.00   0.0  0.00
# 3  2014.09.16  광양시  0.000   0.00    0.043   0.01  0.000  0.00   0.0  0.00
# 4  2014.09.16  구례군  0.000   0.00    0.000   0.00  0.000  0.00   0.0  0.00
#
#    ...  벼줄기굴파리  애멸구  끝동매미충  벼물바구미  멸강나방  이화명나방1화기  벼검은줄오갈병  오갈병  이삭누룩병  \
# 0  ...     NaN  NaN    NaN    NaN   NaN       NaN      NaN  NaN    NaN
# 1  ...     NaN  NaN    NaN    NaN   NaN       NaN      NaN  NaN    NaN
# 2  ...     NaN  NaN    NaN    NaN   NaN       NaN      NaN  NaN    NaN
# 3  ...     NaN  NaN    NaN    NaN   NaN       NaN      NaN  NaN    NaN
# 4  ...     NaN  NaN    NaN    NaN   NaN       NaN      NaN  NaN    NaN
#
#    이화명나방2화기
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### [벼멸구]
