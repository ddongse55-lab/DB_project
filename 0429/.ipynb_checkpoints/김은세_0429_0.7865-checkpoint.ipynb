# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## [문제] 인터넷 신규 가입 여부 예측 하는 예제를 구현하시오.
#
# #### 제출할 파일명: 홍길동_0429_정확도.ipynb
#
# #### <처리 조건>
# - logistic regression 모델을 사용한다.
# - 데이터 로드 : pd.read_csv('newbie.csv')
# - 종속 변수 : 'Newbie'
# - 독립 변수 제거 : 'who', 'Country', 'Years on Internet‘
# - 결측값 처리 :
# 	- Age : 평균으로 채움
# 	- Household Income, Sexual Preference, Marital Status : 최빈값으로 채움
# - 범주형 독립변수 원핫인코딩 처리 : pd.get_dummies() 사용
# - test 데이터 사이즈는 20%, train 데이터는 80%로 한다.(train_test_split 사용할것)
# - 최종적으로 모델을 만든 후 정확도(accuracy)를 출력하도록 한다.

# %% [markdown]
# #### 데이터 로드

# %%
import pandas as pd

newbie = pd.read_csv('newbie.csv')
newbie.head(50)
# Out:
#         who  Newbie   Age  Gender Household Income Sexual Preference  \
# 0   id74364       0  54.0    Male           $50-74          Gay male
# 1   id84505       0  39.0  Female        Over $100      Heterosexual
# 2   id84509       1  49.0  Female           $40-49      Heterosexual
# 3   id87028       1  22.0  Female           $40-49      Heterosexual
# 4   id76087       0  20.0    Male           $30-39          Bisexual
# 5   id77190       0  16.0    Male              NaN      Heterosexual
# 6   id78923       0  67.0    Male           $30-39      Heterosexual
# 7   id78976       0  25.0    Male        Under $10      Heterosexual
# 8   id89941       0  54.0    Male           $75-99      Heterosexual
# 9   id75957       1  48.0  Female           $50-74      Heterosexual
# 10  id76313       0  25.0    Male           $30-39      Heterosexual
# 11  id80575       0  27.0  Female           $40-49          Bisexual
# 12  id87146       1  42.0    Male           $50-74      Heterosexual
# ...

# %% [markdown]
# #### 독립 변수 제거

# %%
newbie = newbie.drop(['who', 'Country', 'Years on Internet'], axis=1)
newbie.head(2)
# Out:
#    Newbie   Age  Gender Household Income Sexual Preference  \
# 0       0  54.0    Male           $50-74          Gay male
# 1       0  39.0  Female        Over $100      Heterosexual
#
#   Education Attainment Major Occupation Marital Status
# 0         Some College         Computer          Other
# 1         Professional            Other          Other

# %% [markdown]
# #### 결측값 처리

# %%
from sklearn.impute import SimpleImputer
import numpy as np

imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
age_mean = imp_mean.fit_transform(newbie[['Age']])

newbie['Age'] = age_mean
newbie.head(50)
# Out:
#     Newbie        Age  Gender Household Income Sexual Preference  \
# 0        0  54.000000    Male           $50-74          Gay male
# 1        0  39.000000  Female        Over $100      Heterosexual
# 2        1  49.000000  Female           $40-49      Heterosexual
# 3        1  22.000000  Female           $40-49      Heterosexual
# 4        0  20.000000    Male           $30-39          Bisexual
# 5        0  16.000000    Male              NaN      Heterosexual
# 6        0  67.000000    Male           $30-39      Heterosexual
# 7        0  25.000000    Male        Under $10      Heterosexual
# 8        0  54.000000    Male           $75-99      Heterosexual
# 9        1  48.000000  Female           $50-74      Heterosexual
# 10       0  25.000000    Male           $30-39      Heterosexual
# 11       0  27.000000  Female           $40-49          Bisexual
# 12       1  42.000000    Male           $50-74      Heterosexual
# ...

# %%
imp_most = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

HI_most = imp_most.fit_transform(newbie[['Household Income']])
HI_most_newbie = pd.DataFrame(HI_most)
newbie['Household Income'] = HI_most_newbie[0]

SP_most = imp_most.fit_transform(newbie[['Sexual Preference']])
SP_most_newbie = pd.DataFrame(SP_most)
newbie['Sexual Preference'] = SP_most_newbie[0]

MS_most = imp_most.fit_transform(newbie[['Marital Status']])
MS_most_newbie = pd.DataFrame(MS_most)
newbie['Marital Status'] = MS_most_newbie[0]

newbie.head(50)
# Out:
#     Newbie        Age  Gender Household Income Sexual Preference  \
# 0        0  54.000000    Male           $50-74          Gay male
# 1        0  39.000000  Female        Over $100      Heterosexual
# 2        1  49.000000  Female           $40-49      Heterosexual
# 3        1  22.000000  Female           $40-49      Heterosexual
# 4        0  20.000000    Male           $30-39          Bisexual
# 5        0  16.000000    Male           $50-74      Heterosexual
# 6        0  67.000000    Male           $30-39      Heterosexual
# 7        0  25.000000    Male        Under $10      Heterosexual
# 8        0  54.000000    Male           $75-99      Heterosexual
# 9        1  48.000000  Female           $50-74      Heterosexual
# 10       0  25.000000    Male           $30-39      Heterosexual
# 11       0  27.000000  Female           $40-49          Bisexual
# 12       1  42.000000    Male           $50-74      Heterosexual
# ...

# %% [markdown]
# #### 범주형 독립변수 원핫인코딩 처리

# %%
newbie = pd.get_dummies(newbie, columns=['Gender', 'Household Income', 'Sexual Preference',
                               'Education Attainment', 'Major Occupation', 'Marital Status'],
                       dtype='int')
newbie.head()
# Out:
#    Newbie   Age  Gender_Female  Gender_Male  Household Income_$10-19  \
# 0       0  54.0              0            1                        0
# 1       0  39.0              1            0                        0
# 2       1  49.0              1            0                        0
# 3       1  22.0              1            0                        0
# 4       0  20.0              0            1                        0
#
#    Household Income_$20-29  Household Income_$30-39  Household Income_$40-49  \
# 0                        0                        0                        0
# 1                        0                        0                        0
# 2                        0                        0                        1
# 3                        0                        0                        1
# 4                        0                        1                        0
#
#    Household Income_$50-74  Household Income_$75-99  ...  \
# ...

# %%
newbie.iloc[:, 1:]
# Out:
#         Age  Gender_Female  Gender_Male  Household Income_$10-19  \
# 0      54.0              0            1                        0
# 1      39.0              1            0                        0
# 2      49.0              1            0                        0
# 3      22.0              1            0                        0
# 4      20.0              0            1                        0
# ...     ...            ...          ...                      ...
# 19578  22.0              0            1                        0
# 19579  19.0              0            1                        0
# 19580  49.0              1            0                        0
# 19581  42.0              1            0                        0
# 19582  24.0              1            0                        0
#
#        Household Income_$20-29  Household Income_$30-39  \
# 0                            0                        0
# 1                            0                        0
# ...

# %% [markdown]
# #### train 데이터, test 데이터 설정

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(newbie.iloc[:, 1:], newbie[['Newbie']],
                                                    test_size=0.2,
                                                    random_state=1000)

# %% [markdown]
# #### Logistic Regression (로지스틱 회귀)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver='sag')
model.fit(X_train, y_train)
# Out:
# LogisticRegression(solver='sag')

# %%
score = model.score(X_test, y_test)
print(f'전체 데이터로 예측한 결과 : {score}')
# Out:
# 전체 데이터로 예측한 결과 : 0.7638498851161604

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

model = LogisticRegression(solver='liblinear')
model.fit(X_train_scaled, y_train)
score = model.score(X_test_scaled, y_test)
print(f'전체 데이터로 예측한 결과 : {score}')
# Out:
# 전체 데이터로 예측한 결과 : 0.7641051825376564

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train_standard = scaler.transform(X_train)
X_test_standard = scaler.transform(X_test)

model = LogisticRegression(solver='liblinear')
model.fit(X_train_standard, y_train)
score = model.score(X_test_standard, y_test)
print(f'전체 데이터로 예측한 결과 : {score}')
# Out:
# 전체 데이터로 예측한 결과 : 0.7633392902731683

# %% [markdown]
# #### for문 이용

# %%
from sklearn.model_selection import train_test_split

lst0 = []
for i in range(0, 1501):
    X_train, X_test, y_train, y_test = train_test_split(newbie.iloc[:, 1:], newbie[['Newbie']],
                                                        test_size=0.2,
                                                        random_state=i)
    model = LogisticRegression(solver='sag')
    model.fit(X_train, y_train)
    score = model.score(X_test, y_test)
    lst0.append(score)

print(max(lst0))
# Out:
# 0.7806995149348992

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

lst1 = []
for i in range(0, 1501):
    X_train, X_test, y_train, y_test = train_test_split(newbie.iloc[:, 1:], newbie[['Newbie']],
                                                        test_size=0.2,
                                                        random_state=i)
    scaler = MinMaxScaler()
    scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    model = LogisticRegression(solver='liblinear')
    model.fit(X_train_scaled, y_train)
    score1 = model.score(X_test_scaled, y_test)
    lst1.append(score1)

print(max(lst1))
# Out:
# 0.7806995149348992

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

lst2 = []
for i in range(0, 1501):
    X_train, X_test, y_train, y_test = train_test_split(newbie.iloc[:, 1:], newbie[['Newbie']],
                                                        test_size=0.2,
                                                        random_state=i)
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train_standard = scaler.transform(X_train)
    X_test_standard = scaler.transform(X_test)
    
    model = LogisticRegression(solver='liblinear')
    model.fit(X_train_standard, y_train)
    score2 = model.score(X_test_standard, y_test)
    lst2.append(score2)

print(max(lst2))
# Out:
# 0.7809548123563952

# %% [markdown]
# #### while문 사용

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

i = 1501
while i < 10001:
    X_train, X_test, y_train, y_test = train_test_split(newbie.iloc[:, 1:], newbie[['Newbie']],
                                                        test_size=0.2,
                                                        random_state=i)
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train_standard = scaler.transform(X_train)
    X_test_standard = scaler.transform(X_test)
    
    model = LogisticRegression(solver='liblinear')
    model.fit(X_train_standard, y_train)
    score3 = model.score(X_test_standard, y_test)
    if score3 > 0.7809:
        print('random_state :', i, 'accuracy :', score3)
    i += 1
# Out:
# random_state : 4280 accuracy : 0.7865713556293081
# random_state : 4578 accuracy : 0.78580546336482
# random_state : 9961 accuracy : 0.7817207046208833
